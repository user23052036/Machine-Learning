# %%
# API to fetch the dataset from Kaggle
# !kaggle datasets download -d fanconic/skin-cancer-malignant-vs-benign -p ~/Desktop/Machine-Learning/Data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/fanconic/skin-cancer-malignant-vs-benign
# License(s): unknown
# ...
# 100%|████████████████████████████████████████| 325M/325M [02:41<00:00, 2.06MB/s]
# 100%|████████████████████████████████████████| 325M/325M [02:41<00:00, 2.11MB/s]

# %%
# extracting the compessed Dataset
from zipfile import ZipFile
from pathlib import Path

zip_path = Path.home() / "Desktop/Machine-Learning/Data/skin-cancer-malignant-vs-benign.zip"
extract_dir = Path.home() / "Desktop/Machine-Learning/Data/skin_cancer"

with ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print("Dataset extracted to:", extract_dir)
# Out:
# Dataset extracted to: /home/midori/Desktop/Machine-Learning/Data/skin_cancer
